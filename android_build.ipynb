# %% [markdown]
# # AI Keyboard — Android APK Build
#
# Builds the APK from the GitHub repo using Buildozer on Colab's free Linux VM.
#
# **Run cells top to bottom.** First run takes ~30-45 minutes (Buildozer downloads Android SDK, NDK, etc.). Later runs are much faster (~5-10 min) as long as the same Colab session is alive.
#
# When done, the APK appears in the `ai-communication-assistant/bin/` folder and the last cell auto-downloads it.

# %% [markdown]
# ## 1. Install Buildozer + system dependencies

# %%
# !sudo apt update -qq
# !sudo apt install -y -qq \
    git zip unzip openjdk-17-jdk python3-pip autoconf libtool pkg-config \
    zlib1g-dev libncurses-dev libncursesw5-dev libtinfo6 cmake libffi-dev libssl-dev

# !pip install --upgrade buildozer cython==0.29.36 virtualenv
# !buildozer --version
# Out:
# 7 packages can be upgraded. Run 'apt list --upgradable' to see them.
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# autoconf is already the newest version (2.71-2).
# autoconf set to manually installed.
# libffi-dev is already the newest version (3.4.2-4).
# libffi-dev set to manually installed.
# zip is already the newest version (3.0-12build2).
# cmake is already the newest version (3.22.1-1ubuntu1.22.04.2).
# git is already the newest version (1:2.34.1-1ubuntu1.17).
# libncurses-dev is already the newest version (6.3-2ubuntu0.1).
# libncurses-dev set to manually installed.
# libssl-dev is already the newest version (3.0.2-0ubuntu1.23).
# libtinfo6 is already the newest version (6.3-2ubuntu0.1).
# unzip is already the newest version (6.0-26ubuntu3.2).
# zlib1g-dev is already the newest version (1:1.2.11.dfsg-2ubuntu9.2).
# ...

# %% [markdown]
# ## 2. Clone your GitHub repo

# %%
# Pulls the latest code from GitHub. Re-run this cell to get any updates you've pushed.
# !rm -rf ai-communication-assistant
# !git clone https://github.com/riteshkadtan007-oss/ai-communication-assistant.git
# %cd ai-communication-assistant
# !ls -la
# Out:
# Cloning into 'ai-communication-assistant'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 15 (delta 1), reused 15 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (15/15), 18.79 KiB | 3.13 MiB/s, done.
# Resolving deltas: 100% (1/1), done.
# /content/ai-communication-assistant
# total 88
# drwxr-xr-x 3 root root  4096 May 15 07:18 .
# drwxr-xr-x 1 root root  4096 May 15 07:18 ..
# -rw-r--r-- 1 root root  3739 May 15 07:18 android_build.ipynb
# -rw-r--r-- 1 root root  3157 May 15 07:18 buildozer.spec
# -rw-r--r-- 1 root root  1383 May 15 07:18 config.py
# -rw-r--r-- 1 root root  6722 May 15 07:18 gemini_client.py
# drwxr-xr-x 8 root root  4096 May 15 07:18 .git
# -rw-r--r-- 1 root root   460 May 15 07:18 .gitignore
# -rw-r--r-- 1 root root  1977 May 15 07:18 list_models.py
# -rw-r--r-- 1 root root 23086 May 15 07:18 main.py
# ...

# %% [markdown]
# ## 3. Build the APK (slow first time, ~30-45 min)
#
# Buildozer will download the Android SDK, NDK, build tools, Python-for-Android, and your dependencies. Watch the output — if it fails, the error is usually near the bottom and tells you what's missing.
#
# **Don't close the Colab tab while this runs.** Colab will idle-disconnect if your browser tab is hidden for too long.

# %%
# !yes | buildozer -v android debug 2>&1 | tail -300
# Out:
#       |                                       ^
# /content/ai-communication-assistant/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_21/python3/android-build/android-root/include/python3.14/cpython/pystate.h:220:1: note: '_PyThreadState_UncheckedGet' has been explicitly marked deprecated here
#   220 | Py_DEPRECATED(3.14) static inline PyThreadState*
#       | ^
# /content/ai-communication-assistant/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_21/python3/android-build/android-root/include/python3.14/pyport.h:281:54: note: expanded from macro 'Py_DEPRECATED'
#   281 | #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#       |                                                      ^
# ...

# %% [markdown]
# ## 4. Find the built APK

# %%
import glob
apks = sorted(glob.glob('bin/*.apk'))
for apk in apks:
    import os
    size_mb = os.path.getsize(apk) / (1024 * 1024)
    print(f'{apk}  ({size_mb:.1f} MB)')

if not apks:
    print('No APK found. Build probably failed — scroll up in cell 3 output to find the error.')
# Out:
# No APK found. Build probably failed — scroll up in cell 3 output to find the error.

# %% [markdown]
# ## 5. Download the APK to your Mac

# %%
from google.colab import files
import glob

apks = sorted(glob.glob('bin/*.apk'))
if apks:
    files.download(apks[-1])
    print(f'Downloading {apks[-1]} to your Downloads folder...')
else:
    print('No APK to download. Check cell 3 output for build errors.')
# Out:
# No APK to download. Check cell 3 output for build errors.

# %%
# %cd /content
# !rm -rf ai-communication-assistant
# !rm -rf /root/.buildozer
# !pip install --upgrade buildozer cython==0.29.36 virtualenv
# !git clone https://github.com/riteshkadtan007-oss/ai-communication-assistant.git
# %cd ai-communication-assistant

# Sanity check — these should all match what's on GitHub:
print("---- spec sanity check ----")
# !grep -E "p4a.branch|android.archs|^requirements" buildozer.spec
# Out:
# /content
# ...
# WARNING: Cache entry deserialization failed, entry ignored
# ...
# Cloning into 'ai-communication-assistant'...
# remote: Enumerating objects: 18, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 18 (delta 3), reused 17 (delta 2), pack-reused 0 (from 0)
# Receiving objects: 100% (18/18), 19.62 KiB | 9.81 MiB/s, done.
# Resolving deltas: 100% (3/3), done.
# /content/ai-communication-assistant
# ---- spec sanity check ----
# requirements = python3,kivy==2.3.0,requests,openssl
# android.archs = arm64-v8a
# p4a.branch = v2024.01.21

# %%
# !yes | buildozer -v android debug 2>&1 | tail -200
# Out:
# [DEBUG]:   	/content/ai-communication-assistant/.buildozer/android/platform/build-arm64-v8a/dists/aikeyboard/_python_bundle__arm64-v8a/_python_bundle/modules/_struct.cpython-311.so
# [DEBUG]:   	/content/ai-communication-assistant/.buildozer/android/platform/build-arm64-v8a/dists/aikeyboard/_python_bundle__arm64-v8a/_python_bundle/modules/_multiprocessing.cpython-311.so
# [DEBUG]:   	/content/ai-communication-assistant/.buildozer/android/platform/build-arm64-v8a/dists/aikeyboard/_python_bundle__arm64-v8a/_python_bundle/modules/_queue.cpython-311.so
# [DEBUG]:   	/content/ai-communication-assistant/.buildozer/android/platform/build-arm64-v8a/dists/aikeyboard/_python_bundle__arm64-v8a/_python_bundle/modules/_codecs_tw.cpython-311.so
# [DEBUG]:   	/content/ai-communication-assistant/.buildozer/android/platform/build-arm64-v8a/dists/aikeyboard/_python_bundle__arm64-v8a/_python_bundle/modules/xxlimited.cpython-311.so
# ...

# %%
from google.colab import files
import glob, os

apks = sorted(glob.glob('bin/*.apk'))
if apks:
    apk = apks[-1]
    size_mb = os.path.getsize(apk) / (1024 * 1024)
    print(f"Downloading {apk} ({size_mb:.1f} MB)...")
    files.download(apk)
else:
    print("No APK found in bin/")

# %%
# %cd /content/ai-communication-assistant
# !git pull
# !yes | buildozer -v android debug 2>&1 | tail -100
# Out:
# /content/ai-communication-assistant
# Already up to date.
# ^C

# %%
# %cd /content

# 1. Install system packages (~2 min)
# !sudo apt update -qq
# !sudo apt install -y -qq \
    git zip unzip openjdk-17-jdk python3-pip autoconf libtool pkg-config \
    zlib1g-dev libncurses-dev libncursesw5-dev libtinfo6 cmake libffi-dev libssl-dev

# 2. Install Buildozer (~1 min)
# !pip install --upgrade buildozer cython==0.29.36 virtualenv

# 3. Clone the repo (~5 sec)
# !rm -rf ai-communication-assistant
# !git clone https://github.com/riteshkadtan007-oss/ai-communication-assistant.git
# %cd ai-communication-assistant

# 4. Sanity check
print("---- spec sanity check ----")
# !grep -E "p4a.branch|android.archs|^requirements" buildozer.spec
print()
# !buildozer --version
# Out:
# /content
# 6 packages can be upgraded. Run 'apt list --upgradable' to see them.
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# autoconf is already the newest version (2.71-2).
# libffi-dev is already the newest version (3.4.2-4).
# libtool is already the newest version (2.4.6-15build2).
# pkg-config is already the newest version (0.29.2-1ubuntu3).
# zip is already the newest version (3.0-12build2).
# cmake is already the newest version (3.22.1-1ubuntu1.22.04.2).
# git is already the newest version (1:2.34.1-1ubuntu1.17).
# libncurses-dev is already the newest version (6.3-2ubuntu0.1).
# libncursesw5-dev is already the newest version (6.3-2ubuntu0.1).
# libssl-dev is already the newest version (3.0.2-0ubuntu1.23).
# libtinfo6 is already the newest version (6.3-2ubuntu0.1).
# unzip is already the newest version (6.0-26ubuntu3.2).
# ...

# %%
# !yes | buildozer -v android debug 2>&1 | tail -200
# Out:
# [DEBUG]:   	gcc -fPIC -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -std=c11 -Wextra -Wno-unused-parameter -Wno-missing-field-initializers -Werror=implicit-function-declaration -fvisibility=hidden -I/content/ai-communication-assistant/.buildozer/android/platform/build-arm64-v8a/build/other_builds/hostpython3/desktop/hostpython3/Include/internal -I. -IObjects -IPython -I/usr/include/x86_64-linux-gnu -I/usr/local/include -I/content/ai-communication-assistant/.buildozer/android/platform/build-arm64-v8a/build/other_builds/hostpython3/desktop/hostpython3/Include -I/content/ai-communication-assistant/.buildozer/android/platform/build-arm64-v8a/build/other_builds/hostpython3/desktop/hostpython3/native-build -c /content/ai-communication-assistant/.buildozer/android/platform/build-arm64-v8a/build/other_builds/hostpython3/desktop/hostpython3/Modules/termios.c -o build/temp.linux-x86_64-3.11/content/ai-communication-assistant/.buildozer/android/platform/build-arm64-v8a/build/other_builds/hostpyt
# ...

# %%
print("=== What's in the NDK toolchain dir? ===")
# !ls /root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/ 2>&1

print("\n=== Where is clang actually? ===")
# !find /root/.buildozer/android/platform/android-ndk-r25b -name "clang" -type f 2>&1 | head -10

print("\n=== Size of NDK directory (full = ~3GB) ===")
# !du -sh /root/.buildozer/android/platform/android-ndk-r25b 2>&1

print("\n=== Top-level NDK contents ===")
# !ls /root/.buildozer/android/platform/android-ndk-r25b/ 2>&1 | head -20
# Out:
# === What's in the NDK toolchain dir? ===
# linux-x86_64
#
# === Where is clang actually? ===
# /root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/bin/clang
#
# === Size of NDK directory (full = ~3GB) ===
# 1.2G	/root/.buildozer/android/platform/android-ndk-r25b
#
# === Top-level NDK contents ===
# build
# CHANGELOG.md
# meta
# ndk-build
# ndk-lldb
# ndk-stack
# ndk-which
# NOTICE
# NOTICE.toolchain
# prebuilt
# python-packages
# README.md
# simpleperf
# source.properties
# sources
# toolchains
# wrap.sh

# %%
print("=== Can clang actually run? ===")
# !/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/bin/clang --version 2>&1

print("\n=== File details ===")
# !ls -la /root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/bin/clang
# !file /root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/bin/clang 2>&1
# Out:
# === Can clang actually run? ===
# /bin/bash: line 1: /root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/bin/clang: Permission denied
#
# === File details ===
# -rw-r--r-- 1 root root 8 May 15 10:32 /root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/bin/clang
# /root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/bin/clang: ASCII text, with no line terminators

# %%
import shutil, os
ndk_path = "/root/.buildozer/android/platform/android-ndk-r25b"
if os.path.exists(ndk_path):
    print(f"Deleting partial NDK ({ndk_path})...")
    shutil.rmtree(ndk_path)
    print("Done.")
else:
    print("NDK already gone.")

# Also delete the marker file so buildozer knows to re-download:
# !rm -f /root/.buildozer/android/platform/android-ndk-r25b.tar.bz2*
print("\nReady for retry.")
# Out:
# Deleting partial NDK (/root/.buildozer/android/platform/android-ndk-r25b)...
# Done.
#
# Ready for retry.

# %%
# %cd /content/ai-communication-assistant
# !yes | buildozer -v android debug 2>&1 | tail -200
# Out:
# /content/ai-communication-assistant
